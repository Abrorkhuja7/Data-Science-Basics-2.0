# %% [markdown]
# # Day 09. Exercise 02
# # Metrics

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# 1. Create the same dataframe as in the previous exercise.
# 2. Using `train_test_split` with parameters `test_size=0.2`, `random_state=21` get `X_train`, `y_train`, `X_test`, `y_test`. Use the additional parameter `stratify`.

# %%
df = pd.read_csv('../data/dayofweek.csv')

X = df.drop('dayofweek', axis=1)
y = df['dayofweek']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=21,
    stratify=y
)

# %% [markdown]
# ## 2. SVM

# %% [markdown]
# 1. Use the best parameters from the previous exercise and train the model of SVM.
# 2. You need to calculate `accuracy`, `precision`, `recall`, `ROC AUC`.
#
#  - `precision` and `recall` should be calculated for each class (use `average='weighted'`)
#  - `ROC AUC` should be calculated for each class against any other class (all possible pairwise combinations) and then weighted average should be applied for the final metric
#  - the code in the cell should display the result as below:
#
# ```
# accuracy is 0.88757
# precision is 0.89267
# recall is 0.88757
# roc_auc is 0.97878
# ```

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = SVC(
    C=10,
    kernel='rbf',
    gamma='auto',
    class_weight=None,
    probability=True,
    random_state=21
)

model.fit(X_train, y_train)
# Out:
# SVC(C=10, gamma='auto', probability=True, random_state=21)

# %%
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average='weighted')
rec = recall_score(y_test, y_pred, average='weighted')

# %%
classes = sorted(y.unique())
y_test_bin = label_binarize(y_test, classes=classes)

roc = roc_auc_score(
    y_test_bin,
    y_proba,
    average='weighted',
    multi_class='ovr'
)

# %%
print(f"accuracy is {acc:.5f}")
print(f"precision is {prec:.5f}")
print(f"recall is {rec:.5f}")
print(f"roc_auc is {roc:.5f}")
# Out:
# accuracy is 0.85503
# precision is 0.85721
# recall is 0.85503
# roc_auc is 0.97323

# %% [markdown]
# ## 3. Decision tree

# %% [markdown]
# 1. The same task for decision tree

# %%
model = DecisionTreeClassifier(
    max_depth=25,
    criterion='entropy',
    class_weight='balanced',
    random_state=21
)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=25, random_state=21)

# %%
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average='weighted')
rec = recall_score(y_test, y_pred, average='weighted')

# %%
classes = sorted(y.unique())
y_test_bin = label_binarize(y_test, classes=classes)

roc = roc_auc_score(
    y_test_bin,
    y_proba,
    average='weighted',
    multi_class='ovr'
)

# %%
print(f"accuracy is {acc:.5f}")
print(f"precision is {prec:.5f}")
print(f"recall is {rec:.5f}")
print(f"roc_auc is {roc:.5f}")
# Out:
# accuracy is 0.90828
# precision is 0.90987
# recall is 0.90828
# roc_auc is 0.94652

# %% [markdown]
# ## 4. Random forest

# %% [markdown]
# 1. The same task for random forest.

# %%
model = RandomForestClassifier(
    n_estimators=100,
    max_depth=20,
    criterion='entropy',
    class_weight=None,
    random_state=21
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=20, random_state=21)

# %%
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average='weighted')
rec = recall_score(y_test, y_pred, average='weighted')

# %%
classes = sorted(y.unique())
y_test_bin = label_binarize(y_test, classes=classes)

roc = roc_auc_score(
    y_test_bin,
    y_proba,
    average='weighted',
    multi_class='ovr'
)

# %%
print(f"accuracy is {acc:.5f}")
print(f"precision is {prec:.5f}")
print(f"recall is {rec:.5f}")
print(f"roc_auc is {roc:.5f}")
# Out:
# accuracy is 0.93195
# precision is 0.93480
# recall is 0.93195
# roc_auc is 0.98922

# %% [markdown]
# ## 5. Predictions

# %% [markdown]
# 1. Choose the best model.
# 2. Analyze: for which `weekday` your model makes the most errors (in % of the total number of samples of that class in your full dataset), for which `labname` and for which `users`.
# 3. Save the model.

# %%
model = RandomForestClassifier(
    n_estimators=100,
    max_depth=20,
    criterion='entropy',
    class_weight=None,
    random_state=21
)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
df_res = pd.DataFrame({
    'true': y_test,
    'pred': y_pred
})

errors = df_res[df_res['true'] != df_res['pred']]

weekday_error = (
    errors['true'].value_counts() /
    df_res['true'].value_counts()
) * 100

print(weekday_error.sort_values(ascending=False))
# Out:
# true
# 0    22.222222
# 4    14.285714
# 1     9.090909
# 2     6.666667
# 5     5.555556
# 6     2.816901
# 3     2.500000
# Name: count, dtype: float64

# %%
X_columns = df.drop(columns=['dayofweek']).columns
X_test_df = pd.DataFrame(X_test, columns=X_columns)

df_res['labname'] = X_test_df.filter(like='labname').idxmax(axis=1)

# %%
df_res['labname'] = X_test_df.filter(like='labname').idxmax(axis=1)

lab_errors = df_res[df_res['true'] != df_res['pred']]

lab_error_percent = (
    lab_errors['labname'].value_counts() /
    df_res['labname'].value_counts()
).fillna(0) * 100

print(lab_error_percent.sort_values(ascending=False))
# Out:
# labname
# labname_laba05      75.000000
# labname_lab05s      50.000000
# labname_project1    11.428571
# labname_code_rvw     0.000000
# labname_lab03        0.000000
# labname_laba04       0.000000
# labname_lab03s       0.000000
# labname_laba04s      0.000000
# labname_laba06s      0.000000
# Name: count, dtype: float64

# %% [markdown]
# ## 6. Function

# %% [markdown]
# 1. Write a function that takes a list of different models and a corresponding list of parameters (dicts) and returns a dict that contains all the 4 metrics for each model.

# %%
def evaluate_models(models, params_list, X_train, y_train, X_test, y_test):
    results = {}

    classes = sorted(y_train.unique())
    y_test_bin = label_binarize(y_test, classes=classes)

    for model, params in zip(models, params_list):
        model.set_params(**params)
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred, average='weighted')
        rec = recall_score(y_test, y_pred, average='weighted')
        roc = roc_auc_score(y_test_bin, y_proba, average='weighted', multi_class='ovr')

        results[type(model).__name__] = {
            'accuracy': acc,
            'precision': prec,
            'recall': rec,
            'roc_auc': roc
        }

    return results

# %%
# EXAMPLE USAGE 

# models = [
#     SVC(probability=True, random_state=21),
#     DecisionTreeClassifier(random_state=21),
#     RandomForestClassifier(random_state=21)
# ]

# params_list = [
#     {'C': 10, 'kernel': 'rbf', 'gamma': 'auto'},
#     {'max_depth': 25, 'criterion': 'entropy', 'class_weight': 'balanced'},
#     {'n_estimators': 100, 'max_depth': 20, 'criterion': 'entropy'}
# ]

# results = evaluate_models(models, params_list, X_train, y_train, X_test, y_test)
# print(results)
